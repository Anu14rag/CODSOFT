# %% [markdown]
# # Import the liberaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Read .dat file movie
with open("movies12.csv", 'r') as file:
    dat_content = file.readlines()

data = [line.strip().split('::') for line in dat_content]

# Create a DataFrame
df = pd.DataFrame(data, columns=['MovieID', 'Title', 'Genres'])

# Save DataFrame as CSV
df.to_csv('movie1.csv', index=False)

# %%
df_mov = pd.read_csv('movie1.csv')
df_mov
# Out:
#       MovieID                               Title  \
# 0           1                    Toy Story (1995)
# 1           2                      Jumanji (1995)
# 2           3             Grumpier Old Men (1995)
# 3           4            Waiting to Exhale (1995)
# 4           5  Father of the Bride Part II (1995)
# ...       ...                                 ...
# 3878     3948             Meet the Parents (2000)
# 3879     3949          Requiem for a Dream (2000)
# 3880     3950                    Tigerland (2000)
# 3881     3951             Two Family House (2000)
# 3882     3952               Contender, The (2000)
#
#                             Genres
# 0      Animation|Children's|Comedy
# 1     Adventure|Children's|Fantasy
# 2                   Comedy|Romance
# 3                     Comedy|Drama
# 4                           Comedy
# ...                            ...
# 3878                        Comedy
# 3879                         Drama
# 3880                         Drama
# ...

# %%
df_mov.describe()
# Out:
#            MovieID
# count  3883.000000
# mean   1986.049446
# std    1146.778349
# min       1.000000
# 25%     982.500000
# 50%    2010.000000
# 75%    2980.500000
# max    3952.000000

# %%
df_mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   MovieID  3883 non-null   int64
#  1   Title    3883 non-null   object
#  2   Genres   3883 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 91.1+ KB

# %%
df_mov.isnull().sum()
# Out:
# MovieID    0
# Title      0
# Genres     0
# dtype: int64

# %%
# Read .dat file of ratings
with open("E:\\ratings.dat", 'r') as file:
    dat_content = file.readlines()

data = [line.strip().split('::') for line in dat_content]

# Create a DataFrame
df1 = pd.DataFrame(data, columns=['UserID', 'MovieIDs', 'Rating','Timestamp'])

# Save DataFrame as CSV
df1.to_csv('rating.csv', index=False)

# %%
df_rat = pd.read_csv('rating.csv')
df_rat
# Out:
#          UserID  MovieIDs  Rating  Timestamp
# 0             1      1193       5  978300760
# 1             1       661       3  978302109
# 2             1       914       3  978301968
# 3             1      3408       4  978300275
# 4             1      2355       5  978824291
# ...         ...       ...     ...        ...
# 1000204    6040      1091       1  956716541
# 1000205    6040      1094       5  956704887
# 1000206    6040       562       5  956704746
# 1000207    6040      1096       4  956715648
# 1000208    6040      1097       4  956715569
#
# [1000209 rows x 4 columns]

# %%
df_rat.describe()
# Out:
#              UserID      MovieIDs        Rating     Timestamp
# count  1.000209e+06  1.000209e+06  1.000209e+06  1.000209e+06
# mean   3.024512e+03  1.865540e+03  3.581564e+00  9.722437e+08
# std    1.728413e+03  1.096041e+03  1.117102e+00  1.215256e+07
# min    1.000000e+00  1.000000e+00  1.000000e+00  9.567039e+08
# 25%    1.506000e+03  1.030000e+03  3.000000e+00  9.653026e+08
# 50%    3.070000e+03  1.835000e+03  4.000000e+00  9.730180e+08
# 75%    4.476000e+03  2.770000e+03  4.000000e+00  9.752209e+08
# max    6.040000e+03  3.952000e+03  5.000000e+00  1.046455e+09

# %%
df_rat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000209 entries, 0 to 1000208
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   UserID     1000209 non-null  int64
#  1   MovieIDs   1000209 non-null  int64
#  2   Rating     1000209 non-null  int64
#  3   Timestamp  1000209 non-null  int64
# dtypes: int64(4)
# memory usage: 30.5 MB

# %%
df_rat.isnull().sum()
# Out:
# UserID       0
# MovieIDs     0
# Rating       0
# Timestamp    0
# dtype: int64

# %%
# Read .dat file of user
with open("E:\\users.dat", 'r') as file:
    dat_content = file.readlines()

data = [line.strip().split('::') for line in dat_content]

# Create a DataFrame
df1 = pd.DataFrame(data, columns=['UserID', 'Gender', 'Age','Occupation','Zip-code'])

# Save DataFrame as CSV
df1.to_csv('user.csv', index=False)

# %%
df_use = pd.read_csv('user.csv')
df_use
# Out:
#       UserID Gender  Age  Occupation Zip-code
# 0          1      F    1          10    48067
# 1          2      M   56          16    70072
# 2          3      M   25          15    55117
# 3          4      M   45           7    02460
# 4          5      M   25          20    55455
# ...      ...    ...  ...         ...      ...
# 6035    6036      F   25          15    32603
# 6036    6037      F   45           1    76006
# 6037    6038      F   56           1    14706
# 6038    6039      F   45           0    01060
# 6039    6040      M   25           6    11106
#
# [6040 rows x 5 columns]

# %%
df_use.describe()
# Out:
#             UserID          Age   Occupation
# count  6040.000000  6040.000000  6040.000000
# mean   3020.500000    30.639238     8.146854
# std    1743.742145    12.895962     6.329511
# min       1.000000     1.000000     0.000000
# 25%    1510.750000    25.000000     3.000000
# 50%    3020.500000    25.000000     7.000000
# 75%    4530.250000    35.000000    14.000000
# max    6040.000000    56.000000    20.000000

# %%
df_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6040 entries, 0 to 6039
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UserID      6040 non-null   int64
#  1   Gender      6040 non-null   object
#  2   Age         6040 non-null   int64
#  3   Occupation  6040 non-null   int64
#  4   Zip-code    6040 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 236.1+ KB

# %%
df_use.isnull().sum()
# Out:
# UserID        0
# Gender        0
# Age           0
# Occupation    0
# Zip-code      0
# dtype: int64

# %%
df_main = pd.concat([df_mov, df_rat, df_use],axis=1)

# %%
df_main
# Out:
#          MovieID                               Title  \
# 0            1.0                    Toy Story (1995)
# 1            2.0                      Jumanji (1995)
# 2            3.0             Grumpier Old Men (1995)
# 3            4.0            Waiting to Exhale (1995)
# 4            5.0  Father of the Bride Part II (1995)
# ...          ...                                 ...
# 1000204      NaN                                 NaN
# 1000205      NaN                                 NaN
# 1000206      NaN                                 NaN
# 1000207      NaN                                 NaN
# 1000208      NaN                                 NaN
#
#                                Genres  UserID  MovieIDs  Rating  Timestamp  \
# 0         Animation|Children's|Comedy       1      1193       5  978300760
# 1        Adventure|Children's|Fantasy       1       661       3  978302109
# 2                      Comedy|Romance       1       914       3  978301968
# ...

# %%
df_final = df_main.dropna()

# %%
df_final.isnull().sum()
# Out:
# MovieID       0
# Title         0
# Genres        0
# UserID        0
# MovieIDs      0
# Rating        0
# Timestamp     0
# UserID        0
# Gender        0
# Age           0
# Occupation    0
# Zip-code      0
# dtype: int64

# %%
df_final
# Out:
#       MovieID                               Title  \
# 0         1.0                    Toy Story (1995)
# 1         2.0                      Jumanji (1995)
# 2         3.0             Grumpier Old Men (1995)
# 3         4.0            Waiting to Exhale (1995)
# 4         5.0  Father of the Bride Part II (1995)
# ...       ...                                 ...
# 3878   3948.0             Meet the Parents (2000)
# 3879   3949.0          Requiem for a Dream (2000)
# 3880   3950.0                    Tigerland (2000)
# 3881   3951.0             Two Family House (2000)
# 3882   3952.0               Contender, The (2000)
#
#                             Genres  UserID  MovieIDs  Rating  Timestamp  \
# 0      Animation|Children's|Comedy       1      1193       5  978300760
# 1     Adventure|Children's|Fantasy       1       661       3  978302109
# 2                   Comedy|Romance       1       914       3  978301968
# ...

# %%
#visulazation
sns.countplot( x= 'Gender' , hue= 'Rating', data= df_final)
sns.set_theme(style="darkgrid")

# %%
sns.histplot(data=df_final, x="Age", hue="Rating")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
# the histogram of the data
plt.hist(x=df_final['Age'], density=False, bins=20, facecolor='y', alpha=0.75)
plt.xlabel('Rating')
plt.ylabel('Movieid')
plt.grid(True)
plt.show()

# %%
#countplot of rating
sns.countplot(data=df_final,x="Rating")
plt.title('Rating Count')
# Out:
# Text(0.5, 1.0, 'Rating Count')

# %%
plt.hist(x=df_final['MovieIDs'], density=False,bins=25, facecolor='g', alpha=0.75)
plt.xlabel('movies id')
plt.ylabel('rating')
plt.grid(True)
plt.show()

# %%
sns.countplot(x=df_final['Age'],hue=df_final["Rating"],palette='rainbow',
    saturation=0.75)
plt.xlabel='Age'
plt.ylabel='count'
plt.show()

# %%
#Transforming data
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

df_final['Gender'] = encoder.fit_transform(df_final['Gender'])

# %%
X = df_final.drop(['MovieID','Title','Rating','Timestamp','Occupation','Zip-code','Genres'],axis=1)
X
# Out:
#       UserID  MovieIDs  UserID  Gender   Age
# 0          1      1193     1.0       0   1.0
# 1          1       661     2.0       1  56.0
# 2          1       914     3.0       1  25.0
# 3          1      3408     4.0       1  45.0
# 4          1      2355     5.0       1  25.0
# ...      ...       ...     ...     ...   ...
# 3878      28       334  3879.0       1  25.0
# 3879      28       266  3880.0       1  25.0
# 3880      28      2174  3881.0       1  18.0
# 3881      28       912  3882.0       1  56.0
# 3882      28      2248  3883.0       1  50.0
#
# [3883 rows x 5 columns]

# %%
y=df_final['Rating']
y
# Out:
# 0       5
# 1       3
# 2       3
# 3       4
# 4       5
#        ..
# 3878    4
# 3879    2
# 3880    3
# 3881    5
# 3882    4
# Name: Rating, Length: 3883, dtype: int64

# %%
X.head()
# Out:
#    UserID  MovieIDs  UserID  Gender   Age
# 0       1      1193     1.0       0   1.0
# 1       1       661     2.0       1  56.0
# 2       1       914     3.0       1  25.0
# 3       1      3408     4.0       1  45.0
# 4       1      2355     5.0       1  25.0

# %%
#transforming the data
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaled_features = scaler.fit_transform(X)

scaled_df = pd.DataFrame(scaled_features, columns=X.columns)

# %%
#Spliting the data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3, random_state=42)

# %%
#Modelling
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Prediction
y_pred_test =model.predict(X_test)
y_pred_train =model.predict(X_train)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


# Calculate regression metrics
mae = mean_absolute_error(y_test, y_pred_test)
mse = mean_squared_error(y_test, y_pred_test)
rmse = mean_squared_error(y_test, y_pred_test, squared=False)

# Print the regression metrics
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Absolute Error: 0.8809827888525636
# Mean Squared Error: 1.1514308311655301
# Root Mean Squared Error: 1.0730474505656915
